# %% [markdown]
# dataset = https://www.kaggle.com/georgesaavedra/covid19-dataset
#
# 1. Hvilken måned var der flest smittede af corona for hvert land (location)?
# 2. Hvilket land i europa har test flest personer pr. tusinde indbyggere (total_tests_per_thousand), siden juli 2021 til nu?

# %%
import pandas as pd

corona = pd.read_csv('./owid-covid-data.csv',header=0, sep=',')

countries = corona[corona['continent'] == 'North America']

countries
# Out:
#        iso_code      continent       location        date  total_cases  \
# 4423        AIA  North America       Anguilla  2020-03-28          2.0
# 4424        AIA  North America       Anguilla  2020-03-29          2.0
# 4425        AIA  North America       Anguilla  2020-03-30          2.0
# 4426        AIA  North America       Anguilla  2020-03-31          2.0
# 4427        AIA  North America       Anguilla  2020-04-01          2.0
# ...         ...            ...            ...         ...          ...
# 157991      USA  North America  United States  2022-03-01   79091361.0
# 157992      USA  North America  United States  2022-03-02   79143716.0
# 157993      USA  North America  United States  2022-03-03   79196008.0
# 157994      USA  North America  United States  2022-03-04   79250509.0
# 157995      USA  North America  United States  2022-03-05   79265726.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 4423          2.0                 NaN           NaN         NaN
# 4424          0.0                 NaN           NaN         NaN
# 4425          0.0                 NaN           NaN         NaN
# 4426          0.0                 NaN           NaN         NaN
# 4427          0.0                 NaN           NaN         NaN
# ...           ...                 ...           ...         ...
# 157991    47031.0           62331.429      952423.0      1691.0
# 157992    52355.0           57824.857      954518.0      2095.0
# 157993    52292.0           55673.857      956261.0      1743.0
# 157994    54501.0           52764.286      958144.0      1883.0
# 157995    15217.0           47989.857      958437.0       293.0
#
#         new_deaths_smoothed  ...  female_smokers  male_smokers  \
# 4423                    NaN  ...             NaN           NaN
# 4424                    NaN  ...             NaN           NaN
# 4425                    NaN  ...             NaN           NaN
# 4426                    NaN  ...             NaN           NaN
# 4427                    NaN  ...             NaN           NaN
# ...                     ...  ...             ...           ...
# 157991             1830.000  ...            19.1          24.6
# 157992             1725.000  ...            19.1          24.6
# 157993             1553.714  ...            19.1          24.6
# 157994             1497.857  ...            19.1          24.6
# 157995             1425.714  ...            19.1          24.6
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 4423                       NaN                         NaN            81.88
# 4424                       NaN                         NaN            81.88
# 4425                       NaN                         NaN            81.88
# 4426                       NaN                         NaN            81.88
# 4427                       NaN                         NaN            81.88
# ...                        ...                         ...              ...
# 157991                     NaN                        2.77            78.86
# 157992                     NaN                        2.77            78.86
# 157993                     NaN                        2.77            78.86
# 157994                     NaN                        2.77            78.86
# 157995                     NaN                        2.77            78.86
#
#         human_development_index  excess_mortality_cumulative_absolute  \
# 4423                        NaN                                   NaN
# 4424                        NaN                                   NaN
# 4425                        NaN                                   NaN
# 4426                        NaN                                   NaN
# 4427                        NaN                                   NaN
# ...                         ...                                   ...
# 157991                    0.926                                   NaN
# 157992                    0.926                                   NaN
# 157993                    0.926                                   NaN
# 157994                    0.926                                   NaN
# 157995                    0.926                                   NaN
#
#         excess_mortality_cumulative  excess_mortality  \
# 4423                            NaN               NaN
# 4424                            NaN               NaN
# 4425                            NaN               NaN
# 4426                            NaN               NaN
# 4427                            NaN               NaN
# ...                             ...               ...
# 157991                          NaN               NaN
# 157992                          NaN               NaN
# 157993                          NaN               NaN
# 157994                          NaN               NaN
# 157995                          NaN               NaN
#
#         excess_mortality_cumulative_per_million
# 4423                                        NaN
# 4424                                        NaN
# 4425                                        NaN
# 4426                                        NaN
# 4427                                        NaN
# ...                                         ...
# 157991                                      NaN
# 157992                                      NaN
# 157993                                      NaN
# 157994                                      NaN
# 157995                                      NaN
#
# [24931 rows x 67 columns]
